# %%
import pandas as pd
import numpy as np
import time
from seaborn import heatmap
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from utils import evaluate_model, create_sampling_datasets, create_train_test_sampled_split,train_and_evaluate
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.inspection import permutation_importance

# %%
df_preprocessed = pd.read_csv("../../data/preprocessed/PSP_Jan_Feb_2019_preprocessed.csv", sep=";")
df_preprocessed_feature_selection = pd.read_csv("../../data/preprocessed/PSP_Jan_Feb_2019_preprocessed_general_feature_selection.csv", sep=";")

# %%
samplers = samplers = {"RUS": RandomUnderSampler(random_state=42), "ROS": RandomOverSampler(random_state=42)}
prep_data = create_train_test_sampled_split(df_preprocessed, df_preprocessed_feature_selection)

# %%
classifiers = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Support Vector Machine': SVC(probability=True,random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

# %%
feature_set_list, sampling_list, classifier_list, result_list = [],[],[],[]

for feature_set in prep_data.keys():
    # Train and Evaluate non sampled data
    for classifier in classifiers.keys():
        # Each classifier is trained and results written to list
        feature_set_list.append(feature_set)
        sampling_list.append(None)
        classifier_list.append(classifier)
        result_list.append(train_and_evaluate(classifiers[classifier],
                                                         prep_data[feature_set]["X_train"],
                                                         prep_data[feature_set]["y_train"],
                                                         prep_data[feature_set]["X_test"],
                                                         prep_data[feature_set]["y_test"]))
        
    dataset = create_sampling_datasets(samplers,prep_data[feature_set]["X_train"],prep_data[feature_set]["y_train"])
    
    for sampling_tech in dataset.keys():
        # Train and Evaluate RUS and ROS
        for classifier in classifiers.keys():
            # Each classifier is trained and results written to list
            feature_set_list.append(feature_set)
            sampling_list.append(sampling_tech)
            classifier_list.append(classifier)
            result_list.append(train_and_evaluate(classifiers[classifier],
                                                         dataset[sampling_tech][0],
                                                         dataset[sampling_tech][1],
                                                         prep_data[feature_set]["X_test"],
                                                         prep_data[feature_set]["y_test"]))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
metrics = {"classifier":classifier_list,
          "sampling_mode":sampling_list,
          "feature_set":feature_set_list}
for vals, metric in zip([[row[key] for row in result_list] for key in result_list[0].keys()], result_list[0].keys()):
    metrics[metric] = vals

pd.DataFrame(metrics).sort_values("auc_score", ascending=False)
# Out:
#                 classifier sampling_mode        feature_set  accuracy  \
# 3        Gradient Boosting          None       All Features  0.799026
# 11       Gradient Boosting           ROS       All Features  0.596662
# 7        Gradient Boosting           RUS       All Features  0.593682
# 15       Gradient Boosting          None  Selected Features  0.798232
# 23       Gradient Boosting           ROS  Selected Features  0.608484
# 19       Gradient Boosting           RUS  Selected Features  0.604610
# 5            Random Forest           RUS       All Features  0.601133
# 1            Random Forest          None       All Features  0.773694
# 9            Random Forest           ROS       All Features  0.739221
# 17           Random Forest           RUS  Selected Features  0.567057
# 13           Random Forest          None  Selected Features  0.735148
# 21           Random Forest           ROS  Selected Features  0.650507
# 22  Support Vector Machine           ROS  Selected Features  0.567952
# 10  Support Vector Machine           ROS       All Features  0.567554
# 6   Support Vector Machine           RUS       All Features  0.572621
# 18  Support Vector Machine           RUS  Selected Features  0.574012
# 16           Decision Tree           RUS  Selected Features  0.591397
# 4            Decision Tree           RUS       All Features  0.555832
# 0            Decision Tree          None       All Features  0.708325
# 8            Decision Tree           ROS       All Features  0.701967
# 20           Decision Tree           ROS  Selected Features  0.663123
# 14  Support Vector Machine          None  Selected Features  0.798232
# 12           Decision Tree          None  Selected Features  0.741009
# 2   Support Vector Machine          None       All Features  0.798232
#
#     f1_score  precision    recall  auc_score
# 3   0.012689   0.722222  0.006401   0.665638
# 11  0.404343   0.287983  0.678484   0.663823
# 7   0.400645   0.285208  0.673067   0.656660
# 15  0.008785   0.500000  0.004431   0.655511
# 23  0.399146   0.289090  0.644510   0.652782
# 19  0.396421   0.286434  0.643525   0.649740
# 5   0.370788   0.271954  0.582472   0.622528
# 1   0.164956   0.322812  0.110783   0.613825
# 9   0.244169   0.294036  0.208764   0.607309
# 17  0.336278   0.243440  0.543575   0.590649
# 13  0.214496   0.267058  0.179222   0.578891
# 21  0.276429   0.237372  0.330871   0.570468
# 22  0.338957   0.245163  0.548991   0.567394
# 10  0.338751   0.244947  0.548991   0.567035
# 6   0.334674   0.243968  0.532742   0.562919
# 18  0.335606   0.244856  0.533235   0.562844
# 16  0.327612   0.245228  0.493353   0.555221
# 4   0.326758   0.235358  0.534220   0.547663
# 0   0.277203   0.277203  0.277203   0.547358
# 8   0.273959   0.269396  0.278680   0.543656
# 20  0.286256   0.250000  0.334810   0.539390
# 14  0.000000   0.000000  0.000000   0.537899
# 12  0.223414   0.282805  0.184638   0.535317
# 2   0.000000   0.000000  0.000000   0.510030

# %%
df = pd.DataFrame(metrics)
df= df[~df["sampling_mode"].isnull()]
selected_combinations = df[df.groupby("classifier")["auc_score"].transform("max") == df["auc_score"]].reset_index(drop=True)
selected_combinations.head()
# Out:
#                classifier sampling_mode        feature_set  accuracy  \
# 0           Random Forest           RUS       All Features  0.601133
# 1       Gradient Boosting           ROS       All Features  0.596662
# 2           Decision Tree           RUS  Selected Features  0.591397
# 3  Support Vector Machine           ROS  Selected Features  0.567952
#
#    f1_score  precision    recall  auc_score
# 0  0.370788   0.271954  0.582472   0.622528
# 1  0.404343   0.287983  0.678484   0.663823
# 2  0.327612   0.245228  0.493353   0.555221
# 3  0.338957   0.245163  0.548991   0.567394

# %% [markdown]
# ### Erkenntnisse:
#  - GB, LR underfitten extrem auf dem unausgeglichenen Datensatz
#  - DT und RF sind weniger stark davon betroffen
#  - GB bestes Modell ootb
#  - RUS und ROS unterscheiden sich bei GB kaum
#  - RUS ROS nur wenig Auswirkungen auf AUC Score
#  - Wichtig Recall und Prec anzuschauen
#  - Alle Features sind bei GB und LR kontraproduktiv bei DT und RF sind alle features besser.

# %% [markdown]
# ## Hyperparameter Tuning

# %%
class Timer():
    def __init__(self):
        return
    def __enter__(self):
        self.start = time.time()
        return
    def __exit__(self, exc_type, exc_value, tb):
        self.end = time.time()
        print(self.end - self.start)
        return

# %%
dataset_selected = create_sampling_datasets(samplers,
                                   prep_data["Selected Features"]["X_train"],
                                   prep_data["Selected Features"]["y_train"])
dataset_all = create_sampling_datasets(samplers,
                                   prep_data["All Features"]["X_train"],
                                   prep_data["All Features"]["y_train"])

# %%
parameters = {'n_estimators':(100, 120),
              'max_depth':(3,4), 
              'min_samples_split':(2,4),
              'min_samples_leaf':(1,2,4)
             }
clf = classifiers["Gradient Boosting"]
clf_GB = GridSearchCV(clf, 
                      parameters, 
                      refit = "roc_auc", 
                      scoring=["f1","precision","recall","accuracy","roc_auc"], 
                      cv = 5) # CHANGE
with Timer():
    clf_GB.fit(dataset_all["ROS"][0], dataset_all["ROS"][1])
# Out:
# 138.0269432067871

# %%
clf_GB.best_params_
# Out:
# {'max_depth': 4,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 130}

# %%
parameters = {'n_estimators':(50, 100, 200), 
              'criterion':('gini','entropy'), 
              'max_depth':(5,8,11), 
              'min_samples_split':(2,4,8)
             }
clf = classifiers["Random Forest"]
clf_RF = GridSearchCV(clf, 
                      parameters, 
                      refit = "roc_auc", 
                      scoring=["f1","precision","recall","accuracy","roc_auc"], 
                      cv = 5)
with Timer():
    clf_RF.fit(dataset_all["RUS"][0], dataset_all["RUS"][1])
# Out:
# 142.11415147781372

# %%
for clf, feature in zip([clf_GB, clf_RF],["Gradient Boosting","Random Forest"]):
    feature_sel = selected_combinations[selected_combinations["classifier"]==feature].iloc[0]['feature_set']
    print(feature_sel, feature)
    print(clf.best_params_)
    y_pred = clf.predict(prep_data[feature_sel]["X_test"])
    y_prob = clf.predict_proba(prep_data[feature_sel]["X_test"])[:, 1]
    print(evaluate_model(prep_data[feature_sel]["y_test"], y_pred, y_prob))
    #plt.show()
# Out:
# All Features Gradient Boosting
# {'max_depth': 4, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 120}
# {'accuracy': 0.6132525332803497, 'f1_score': 0.40808879428310774, 'precision': 0.29520457545094586, 'recall': 0.6607582471688823, 'auc_score': 0.6706974073607681}
# All Features Random Forest
# {'criterion': 'gini', 'max_depth': 11, 'min_samples_split': 8, 'n_estimators': 200}
# {'accuracy': 0.5924895688456189, 'f1_score': 0.40481717933836336, 'precision': 0.2869779880682987, 'recall': 0.6868537666174298, 'auc_score': 0.6589413560870601}

# %% [markdown]
# # Feature Importance

# %%
clf_GB_tuned = GradientBoostingClassifier(max_depth=4, min_samples_leaf=1, min_samples_split=4, n_estimators=120)
clf_RF_tuned = RandomForestClassifier(criterion="gini",max_depth=11, min_samples_split=8, n_estimators=200)
with Timer():
    clf_GB_tuned.fit(dataset_all["ROS"][0], dataset_all["ROS"][1])
    clf_RF_tuned.fit(dataset_all["RUS"][0], dataset_all["RUS"][1])
# Out:
# 7.985146760940552

# %%
pd.DataFrame([clf_GB_tuned.feature_importances_],columns=dataset_all["RUS"][0].columns)
# Out:
#      amount  3D_secured  previous_attempts  PSP_Moneycard  PSP_Simplecard  \
# 0  0.265095     0.07088           0.053295        0.10135        0.128984
#
#    PSP_UK_Card  country_Germany  country_Switzerland  card_Master  card_Visa  \
# 0     0.120239         0.005134             0.002665     0.083656   0.038247
#
#    ...   hour_20   hour_21   hour_22  hour_23  week_day_1  week_day_2  \
# 0  ...  0.003454  0.002822  0.002292  0.00122    0.006391    0.003187
#
#    week_day_3  week_day_4  week_day_5  week_day_6
# 0    0.007399    0.002317    0.011109    0.005659
#
# [1 rows x 39 columns]

# %%
plt.figure(figsize=(10,3))
plt.bar(range(len(clf_GB_tuned.feature_importances_)), clf_GB_tuned.feature_importances_)
plt.xticks(range(len(clf_GB_tuned.feature_importances_)), dataset_all["RUS"][0].columns, rotation='vertical')
plt.savefig("../../documentation/model-reports/feature_importance_gb.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
pd.DataFrame([clf_RF_tuned.feature_importances_],columns=dataset_all["RUS"][0].columns)
# Out:
#      amount  3D_secured  previous_attempts  PSP_Moneycard  PSP_Simplecard  \
# 0  0.281633    0.056065           0.072997       0.037476        0.087488
#
#    PSP_UK_Card  country_Germany  country_Switzerland  card_Master  card_Visa  \
# 0     0.074135         0.021235             0.017829     0.042225   0.029938
#
#    ...   hour_20   hour_21   hour_22   hour_23  week_day_1  week_day_2  \
# 0  ...  0.006733  0.008199  0.006765  0.006505     0.01704    0.014248
#
#    week_day_3  week_day_4  week_day_5  week_day_6
# 0    0.016029    0.014128    0.017724    0.014899
#
# [1 rows x 39 columns]

# %%
plt.figure(figsize=(10,3))
plt.bar(range(len(clf_RF_tuned.feature_importances_)), clf_RF_tuned.feature_importances_)
plt.xticks(range(len(clf_RF_tuned.feature_importances_)), dataset_all["RUS"][0].columns, rotation='vertical')
plt.savefig("../../documentation/model-reports/feature_importance_rf.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
sns.heatmap(uniform_data, ax=ax1)
sns.heatmap(uniform_data2, ax=ax2)
plt.show()

# %%
feature_set = "All Features"
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(10, 3))
for tuned_clf, clf_name, ax in zip([clf_GB_tuned,clf_RF_tuned],["GB","RF"],[ax1, ax2]):
    y_pred = tuned_clf.predict(prep_data[feature_set]["X_test"])
    y_probs = tuned_clf.predict_proba(prep_data[feature_set]["X_test"])[:, 1]
    res = evaluate_model(prep_data[feature_set]["y_test"], y_pred, y_probs)
    heatmap(res["confusion_matrix"], annot=True, cmap='Blues', fmt='g', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'], ax=ax)
    ax.set_title(f"{clf_name} Konfusionsmatrix")
plt.savefig(f"../../documentation/model-reports/confusion_matrix_GB_RF.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# accuracy :   0.6132525332803497
# f1_score :   0.40808879428310774
# precision :   0.29520457545094586
# recall :   0.6607582471688823
# auc_score :   0.6706974073607681
# confusion_matrix :   [[4831 3204]
#  [ 689 1342]]
# accuracy :   0.5914961255712299
# f1_score :   0.4033662217063262
# precision :   0.2859493931289858
# recall :   0.6843919251600197
# auc_score :   0.6574866789406391
# confusion_matrix :   [[4564 3471]
#  [ 641 1390]]

# %% [markdown]
# # Einbindung in den Unternehmenskontext

# %%
def define_PSP(row):
    if row["PSP_Moneycard"]:
        return "Moneycard"
    if row["PSP_Simplecard"]:
        return "Simplecard"
    if row["PSP_UK_Card"]:
        return "UK_Card"
    else:
        return "Goldcard"

# %%
# Das hier ist noch in Frage zu stellen

feature_set = "All Features"
transaction = prep_data[feature_set]["X_test"].sample(1)
index = transaction.index[0]
real_psp = transaction.apply(define_PSP, axis=1).iloc[0]
transaction.reset_index(drop=True, inplace=True)
permutations = {"Goldcard":[False, False, False],
                "Moneycard":[True, False, False],
                "Simplecard":[False, True, False],
                "UK_Card":[False, False, True]}

success_rates = []
for PSP in permutations.keys():
    transaction.loc[0, "PSP_Moneycard"] = permutations[PSP][0]
    transaction.loc[0, "PSP_Simplecard"] = permutations[PSP][1]
    transaction.loc[0, "PSP_UK_Card"] = permutations[PSP][2]
    success_rates.append(clf_RF_tuned.predict_proba(transaction)[0][1])
df = pd.DataFrame()
df["prob"]=success_rates
df["PSP"]=permutations.keys()
df["real_result"] = prep_data[feature_set]["y_test"].loc[index]
df["real_psp"] = real_psp
df
# Out:
#        prob         PSP  real_result    real_psp
# 0  0.503313    Goldcard        False  Simplecard
# 1  0.446518   Moneycard        False  Simplecard
# 2  0.359050  Simplecard        False  Simplecard
# 3  0.287526     UK_Card        False  Simplecard

# %%
all_probs_all_psp.groupby("index")[""]

# %%
all_dataset = prep_data[feature_set]["X_test"].join(prep_data[feature_set]["y_test"])

# %%
all_dataset["predictions"] = clf_RF_tuned.predict(prep_data[feature_set]["X_test"])
all_dataset["proba"] = clf_RF_tuned.predict_proba(prep_data[feature_set]["X_test"])[:,1]

# %%
all_dataset["PSP"] = all_dataset.apply(define_PSP, axis=1)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
all_dataset["PSP"].unique()
# Out:
# array(['UK_Card', 'Simplecard', 'Moneycard', 'Goldcard'], dtype=object)

# %%
all_dataset["new_pred"] = np.where(all_dataset['proba']>= 0.6, True, False)
print(accuracy_score(all_dataset["predictions"],all_dataset["success"]))
print(accuracy_score(all_dataset["new_pred"],all_dataset["success"]))
print(recall_score(all_dataset["new_pred"],all_dataset["success"]))
print(precision_score(all_dataset["new_pred"],all_dataset["success"]))
print(confusion_matrix(all_dataset["new_pred"],all_dataset["success"]))
# Out:
# 0.5937810451023247
# 0.7578978740313929
# 0.34040880503144655
# 0.21319547021171836
# [[7196 1598]
#  [ 839  433]]

# %% [markdown]
# # Das hat nur zur Folge, dass Recall und Prec sinken -> mehr werden als Falsch klassifiziert -> Bleib bei dem Ansatz Wähle den günstigsten, der Erfolg versspricht.

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt

y_true = # ground truth labels
y_probas = # predicted probabilities generated by sklearn classifier
skplt.metrics.plot_roc_curve(y_true, y_probas)
plt.show()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-plot
#   Downloading scikit_plot-0.3.7-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: matplotlib>=1.4.0 in c:\users\marvi\appdata\roaming\python\python311\site-packages (from scikit-plot) (3.7.3)
# Requirement already satisfied: scikit-learn>=0.18 in c:\programdata\anaconda3\lib\site-packages (from scikit-plot) (1.2.2)
# Requirement already satisfied: scipy>=0.9 in c:\programdata\anaconda3\lib\site-packages (from scikit-plot) (1.11.4)
# Requirement already satisfied: joblib>=0.10 in c:\programdata\anaconda3\lib\site-packages (from scikit-plot) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.20 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=1.4.0->scikit-plot) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=0.18->scikit-plot) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=1.4.0->scikit-plot) (1.16.0)
# Downloading scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# Installing collected packages: scikit-plot
# Successfully installed scikit-plot-0.3.7

# %%
data = all_dataset[(all_dataset["PSP"]=="UK_Card")]

accuracy_score(data["predictions"],data["success"])
# Out:
# 0.2753728628592215

# %%
all_dataset[all_dataset["PSP"]=="Goldcard"].head(50)
# Out:
#        amount  3D_secured  previous_attempts  PSP_Moneycard  PSP_Simplecard  \
# 44688     187        True                  1          False           False
# 13729      88       False                  2          False           False
# 21840     175       False                  0          False           False
# 43656     162       False                  0          False           False
# 48158     280        True                  0          False           False
# 17816     138        True                  0          False           False
# 9961       13       False                  0          False           False
# 22249     179        True                  1          False           False
# 44765     189       False                  0          False           False
# 32935     274        True                  1          False           False
# 16062     120       False                  0          False           False
# 38326     361       False                  0          False           False
# 32397     268        True                  0          False           False
# 27177     219       False                  1          False           False
# 45576     209       False                  1          False           False
# 31872     263       False                  0          False           False
# 12551      68       False                  6          False           False
# 22037     177        True                  0          False           False
# 40233      27       False                  0          False           False
# 9225      349        True                  0          False           False
# 6017      231       False                  0          False           False
# 34250     289       False                  1          False           False
# 7134      261       False                  0          False           False
# 23670     191       False                  0          False           False
# 18519     145       False                  0          False           False
# 3986      179       False                  2          False           False
# 24452     197       False                  0          False           False
# 21748     174       False                  1          False           False
# 15938     118       False                  0          False           False
# 12653      70       False                  3          False           False
# 23394     188        True                  0          False           False
# 33824     284       False                  0          False           False
# 35872     311       False                  0          False           False
# 47659     265       False                  3          False           False
# 18434     144       False                  0          False           False
# 45104     199       False                  0          False           False
# 45061     198       False                  0          False           False
# 2561      137       False                  1          False           False
# 27679     223        True                  1          False           False
# 41727     104        True                  2          False           False
# 16152     121       False                  0          False           False
# 39448     410       False                  0          False           False
# 19015     150       False                  2          False           False
# 29367     238       False                  1          False           False
# 25065     202       False                  2          False           False
# 46430     230       False                  0          False           False
# 43981     169        True                  1          False           False
# 30050     245       False                  0          False           False
# 49368     334       False                  0          False           False
# 37895     350       False                  0          False           False
#
#        PSP_UK_Card  country_Germany  country_Switzerland  card_Master  \
# 44688        False            False                 True         True
# 13729        False             True                False         True
# 21840        False             True                False         True
# 43656        False            False                 True        False
# 48158        False            False                 True         True
# 17816        False             True                False         True
# 9961         False             True                False        False
# 22249        False             True                False         True
# 44765        False            False                 True        False
# 32935        False             True                False        False
# 16062        False             True                False        False
# 38326        False             True                False        False
# 32397        False             True                False         True
# 27177        False             True                False        False
# 45576        False            False                 True         True
# 31872        False             True                False         True
# 12551        False             True                False         True
# 22037        False             True                False        False
# 40233        False            False                 True         True
# 9225         False            False                False         True
# 6017         False            False                False         True
# 34250        False             True                False        False
# 7134         False            False                False        False
# 23670        False             True                False         True
# 18519        False             True                False         True
# 3986         False            False                False         True
# 24452        False             True                False         True
# 21748        False             True                False         True
# 15938        False             True                False         True
# 12653        False             True                False        False
# 23394        False             True                False         True
# 33824        False             True                False         True
# 35872        False             True                False        False
# 47659        False            False                 True         True
# 18434        False             True                False         True
# 45104        False            False                 True         True
# 45061        False            False                 True        False
# 2561         False            False                False        False
# 27679        False             True                False        False
# 41727        False            False                 True        False
# 16152        False             True                False         True
# 39448        False             True                False         True
# 19015        False             True                False         True
# 29367        False             True                False         True
# 25065        False             True                False        False
# 46430        False            False                 True         True
# 43981        False            False                 True         True
# 30050        False             True                False         True
# 49368        False            False                 True        False
# 37895        False             True                False         True
#
#        card_Visa  ...  week_day_1  week_day_2  week_day_3  week_day_4  \
# 44688      False  ...       False       False       False       False
# 13729      False  ...       False       False       False       False
# 21840      False  ...       False       False       False       False
# 43656       True  ...       False       False       False        True
# 48158      False  ...       False       False       False       False
# 17816      False  ...       False        True       False       False
# 9961        True  ...       False       False       False       False
# 22249      False  ...       False       False       False       False
# 44765      False  ...       False       False        True       False
# 32935      False  ...        True       False       False       False
# 16062      False  ...       False        True       False       False
# 38326      False  ...       False       False       False       False
# 32397      False  ...        True       False       False       False
# 27177       True  ...        True       False       False       False
# 45576      False  ...        True       False       False       False
# 31872      False  ...       False       False        True       False
# 12551      False  ...        True       False       False       False
# 22037       True  ...       False        True       False       False
# 40233      False  ...       False       False       False       False
# 9225       False  ...       False       False       False       False
# 6017       False  ...       False       False       False        True
# 34250       True  ...       False       False       False       False
# 7134        True  ...        True       False       False       False
# 23670      False  ...       False       False       False       False
# 18519      False  ...       False       False       False       False
# 3986       False  ...       False       False        True       False
# 24452      False  ...       False       False       False       False
# 21748      False  ...       False       False       False       False
# 15938      False  ...       False       False        True       False
# 12653       True  ...       False       False       False       False
# 23394      False  ...       False       False       False       False
# 33824      False  ...       False       False       False       False
# 35872      False  ...       False       False       False       False
# 47659      False  ...       False       False       False       False
# 18434      False  ...       False        True       False       False
# 45104      False  ...       False        True       False       False
# 45061      False  ...       False        True       False       False
# 2561       False  ...       False       False       False       False
# 27679       True  ...       False       False       False       False
# 41727      False  ...       False        True       False       False
# 16152      False  ...        True       False       False       False
# 39448      False  ...       False        True       False       False
# 19015      False  ...       False       False       False       False
# 29367      False  ...       False        True       False       False
# 25065       True  ...       False       False       False        True
# 46430      False  ...        True       False       False       False
# 43981      False  ...       False       False        True       False
# 30050      False  ...       False       False       False       False
# 49368      False  ...       False       False       False       False
# 37895      False  ...       False       False       False       False
#
#        week_day_5  week_day_6  success  predictions     proba       PSP
# 44688       False        True     True         True  0.697721  Goldcard
# 13729        True       False    False         True  0.727816  Goldcard
# 21840       False        True    False         True  0.718999  Goldcard
# 43656       False       False    False         True  0.631106  Goldcard
# 48158        True       False    False         True  0.778103  Goldcard
# 17816       False       False     True         True  0.771819  Goldcard
# 9961         True       False    False         True  0.647612  Goldcard
# 22249       False        True    False         True  0.697929  Goldcard
# 44765       False       False     True         True  0.698569  Goldcard
# 32935       False       False    False         True  0.714225  Goldcard
# 16062       False       False     True         True  0.709567  Goldcard
# 38326       False        True     True         True  0.729636  Goldcard
# 32397       False       False    False         True  0.753711  Goldcard
# 27177       False       False    False         True  0.653828  Goldcard
# 45576       False       False    False         True  0.642650  Goldcard
# 31872       False       False     True         True  0.598234  Goldcard
# 12551       False       False     True        False  0.362654  Goldcard
# 22037       False       False     True         True  0.803284  Goldcard
# 40233        True       False     True         True  0.751629  Goldcard
# 9225        False       False    False         True  0.777716  Goldcard
# 6017        False       False    False         True  0.690296  Goldcard
# 34250       False        True     True         True  0.657774  Goldcard
# 7134        False       False    False         True  0.596084  Goldcard
# 23670       False       False    False         True  0.676807  Goldcard
# 18519       False       False    False         True  0.680737  Goldcard
# 3986        False       False    False         True  0.680643  Goldcard
# 24452        True       False     True         True  0.718479  Goldcard
# 21748       False       False    False         True  0.653000  Goldcard
# 15938       False       False    False         True  0.690155  Goldcard
# 12653       False       False    False         True  0.717007  Goldcard
# 23394        True       False     True         True  0.771631  Goldcard
# 33824       False        True     True         True  0.698637  Goldcard
# 35872        True       False    False         True  0.726338  Goldcard
# 47659       False       False     True         True  0.708943  Goldcard
# 18434       False       False    False         True  0.690408  Goldcard
# 45104       False       False    False         True  0.642713  Goldcard
# 45061       False       False    False         True  0.687465  Goldcard
# 2561         True       False    False         True  0.737010  Goldcard
# 27679        True       False    False         True  0.745951  Goldcard
# 41727       False       False    False         True  0.718915  Goldcard
# 16152       False       False    False         True  0.681980  Goldcard
# 39448       False       False    False         True  0.605653  Goldcard
# 19015       False       False    False         True  0.688467  Goldcard
# 29367       False       False    False         True  0.660018  Goldcard
# 25065       False       False    False         True  0.629272  Goldcard
# 46430       False       False    False         True  0.732082  Goldcard
# 43981       False       False    False         True  0.631783  Goldcard
# 30050       False        True    False         True  0.709345  Goldcard
# 49368        True       False    False         True  0.640027  Goldcard
# 37895        True       False     True         True  0.722958  Goldcard
#
# [50 rows x 43 columns]

# %% [markdown]
# # Hier scheint ein Bias entstanden zu sein, da Goldcard immer die höchste Wahrscheinlikeit hat.
#
#
# ## Besserer Ansatz evtl: Wenn Modell True entscheidet, dann nimm den günstigsten!

# %%
psp = pd.DataFrame([["Moneycard",5,2],["Goldcard",10,5],["UK_Card",3,1],["Simplecard",1,0.5]],columns = ["psp","amount_success","amount_failed"])
psp.head()
# Out:
#           psp  amount_success  amount_failed
# 0   Moneycard               5            2.0
# 1    Goldcard              10            5.0
# 2     UK_Card               3            1.0
# 3  Simplecard               1            0.5

# %%
permutations = {"Goldcard":[False, False, False],
                "Moneycard":[True, False, False],
                "Simplecard":[False, True, False],
                "UK_Card":[False, False, True]}
transaction = prep_data[feature_set]["X_test"].copy()
all_data = transaction.copy()
all_data["success"] = prep_data[feature_set]["y_test"]
all_data.reset_index(inplace=True)
all_data["psp"] = all_data.apply(define_PSP, axis=1)
data_list=[]
with Timer():
    for row in all_data.to_dict(orient="records"):
        for PSP in permutations.keys():
            if row["psp"] != PSP:
                row["PSP_Moneycard"] = permutations[PSP][0]
                row["PSP_Simplecard"] = permutations[PSP][1]
                row["PSP_UK_Card"] = permutations[PSP][2]
                df_the_dict = pd.DataFrame({'name':row.keys(), 'value':row.values()})
                data_list.append(row)
    all_data_all_psp = pd.concat([all_data, pd.DataFrame(data_list)],ignore_index=True)
# Out:
# 2.7005436420440674

# %%
useful_cols = all_data_all_psp[["index","psp","success"]]
all_data_all_psp.drop(["index","psp","success"],axis=1, inplace=True)
all_data_all_psp["proba"] = clf_GB_tuned.predict_proba(all_data_all_psp)[:,1]

# %%
all_probs_all_psp = all_data_all_psp.join(useful_cols)

# %%
all_probs_all_psp[all_probs_all_psp["proba"]>0.5]
# Out:
#        amount  3D_secured  previous_attempts  PSP_Moneycard  PSP_Simplecard  \
# 0         128        True                  0          False           False
# 2         152       False                  0          False           False
# 3         159       False                  2          False           False
# 6         136       False                  0          False           False
# 11        111       False                  2          False           False
# ...       ...         ...                ...            ...             ...
# 40247     161       False                  0          False           False
# 40248     161       False                  0          False           False
# 40261      78       False                  0          False           False
# 40262      78       False                  0          False           False
# 40263      78       False                  0          False           False
#
#        PSP_UK_Card  country_Germany  country_Switzerland  card_Master  \
# 0             True             True                False         True
# 2             True            False                 True        False
# 3             True             True                False         True
# 6             True             True                False        False
# 11            True             True                False         True
# ...            ...              ...                  ...          ...
# 40247         True             True                False         True
# 40248         True             True                False         True
# 40261         True             True                False         True
# 40262         True             True                False         True
# 40263         True             True                False         True
#
#        card_Visa  ...  week_day_1  week_day_2  week_day_3  week_day_4  \
# 0          False  ...       False       False       False       False
# 2           True  ...       False       False       False       False
# 3          False  ...       False       False        True       False
# 6           True  ...       False       False       False       False
# 11         False  ...        True       False       False       False
# ...          ...  ...         ...         ...         ...         ...
# 40247      False  ...       False       False       False        True
# 40248      False  ...       False       False       False        True
# 40261      False  ...        True       False       False       False
# 40262      False  ...        True       False       False       False
# 40263      False  ...        True       False       False       False
#
#        week_day_5  week_day_6     proba  index         psp  success
# 0           False       False  0.624287  16841     UK_Card    False
# 2            True       False  0.654326  43283     UK_Card     True
# 3           False       False  0.558123  19926     UK_Card    False
# 6            True       False  0.608053  17683     UK_Card     True
# 11          False       False  0.614270  15384     UK_Card    False
# ...           ...         ...       ...    ...         ...      ...
# 40247       False       False  0.572397  20212   Moneycard    False
# 40248       False       False  0.572397  20212   Moneycard    False
# 40261       False       False  0.526597  13129  Simplecard    False
# 40262       False       False  0.526597  13129  Simplecard    False
# 40263       False       False  0.526597  13129  Simplecard    False
#
# [15268 rows x 43 columns]

# %%
def apply_cost(row):
    if row["success"]:
        return row["amount_success"]
    else:
        return row["amount_failed"]
        
all_probs_all_psp = all_probs_all_psp.merge(psp, left_on="psp", right_on="psp")
all_probs_all_psp["cost"] = all_probs_all_psp.apply(apply_cost, axis=1)

# %%
all_probs_all_psp.groupby("index")[""]
# Out:
#        amount  3D_secured  previous_attempts  PSP_Moneycard  PSP_Simplecard  \
# 0         128        True                  0          False           False
# 1         237       False                  0          False           False
# 2         152       False                  0          False           False
# 3         159       False                  2          False           False
# 4         136       False                  0          False           False
# ...       ...         ...                ...            ...             ...
# 40259     303       False                  1          False           False
# 40260     303       False                  1          False           False
# 40261     169       False                  1          False           False
# 40262     169       False                  1          False           False
# 40263     169       False                  1          False           False
#
#        PSP_UK_Card  country_Germany  country_Switzerland  card_Master  \
# 0             True             True                False         True
# 1             True            False                False        False
# 2             True            False                 True        False
# 3             True             True                False         True
# 4             True             True                False        False
# ...            ...              ...                  ...          ...
# 40259         True            False                False         True
# 40260         True            False                False         True
# 40261         True             True                False         True
# 40262         True             True                False         True
# 40263         True             True                False         True
#
#        card_Visa  ...  week_day_4  week_day_5  week_day_6     proba  index  \
# 0          False  ...       False       False       False  0.624287  16841
# 1           True  ...       False       False       False  0.347822   6293
# 2           True  ...       False        True       False  0.654326  43283
# 3          False  ...       False       False       False  0.558123  19926
# 4           True  ...       False        True       False  0.608053  17683
# ...          ...  ...         ...         ...         ...       ...    ...
# 40259      False  ...       False       False       False  0.277930   8374
# 40260      False  ...       False       False       False  0.277930   8374
# 40261      False  ...        True       False       False  0.568780  21111
# 40262      False  ...        True       False       False  0.568780  21111
# 40263      False  ...        True       False       False  0.568780  21111
#
#             psp  success  amount_success  amount_failed  cost
# 0       UK_Card    False               3            1.0   1.0
# 1       UK_Card    False               3            1.0   1.0
# 2       UK_Card     True               3            1.0   3.0
# 3       UK_Card    False               3            1.0   1.0
# 4       UK_Card     True               3            1.0   3.0
# ...         ...      ...             ...            ...   ...
# 40259  Goldcard    False              10            5.0   5.0
# 40260  Goldcard    False              10            5.0   5.0
# 40261  Goldcard     True              10            5.0  10.0
# 40262  Goldcard     True              10            5.0  10.0
# 40263  Goldcard     True              10            5.0  10.0
#
# [40264 rows x 46 columns]

# %% [markdown]
# # Wenn das Modell bei Goldcard wahr vorausgesagt hat: Wie oft war es auch wahr?

# %%
samplers = samplers = {"RUS": RandomUnderSampler(random_state=47), "ROS": RandomOverSampler(random_state=47)}
df_sampled = create_sampling_datasets(df_preprocessed, samplers)
df_sampled_feature_selection = create_sampling_datasets(df_preprocessed_feature_selection, samplers)

# %%
classifiers = {
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Logistic Regression': LogisticRegression(max_iter=10000),
    'Gradient Boosting': GradientBoostingClassifier()
}

# %%
results = {}
for classifier in classifiers.keys():
    print(f"{classifier} results:")
    results[classifier]=[]
    for feature_type, dataset in zip(["All Features","General Feature Selection"],[df_sampled, df_sampled_feature_selection]):
        for sampling_tech in dataset.keys():
            print("Metrics for:", feature_type, "with", sampling_tech, "sampling")
            X_train, X_test, y_train, y_test = train_test_split(dataset[sampling_tech][0], 
                                                            dataset[sampling_tech][1], 
                                                            test_size=0.2, 
                                                            random_state=42)
            result = train_and_evaluate_classifier(classifiers[classifier], X_train, y_train)
            results[classifier].append({"feature_type":feature_type,"sampling_tech":sampling_tech,"result":result})

    print("")
    print("--------------------------------------")

# %%
for feature_type, dataset in zip(["All Features","General Feature Selection"],[df_sampled, df_sampled_feature_selection]):
    for sampling_tech in dataset.keys():
        print("Metrics for:", feature_type, "with", sampling_tech, "sampling")
        X_train, X_test, y_train, y_test = train_test_split(dataset[sampling_tech][0], 
                                                            dataset[sampling_tech][1], 
                                                            test_size=0.2, 
                                                            random_state=42)
        for classifier in classifiers.keys():
            print(f"{classifier} results:")
            result = train_and_evaluate_classifier(classifiers[classifier], X_train, y_train)
                #results_2[classifier].append({"feature_type":feature_type,"sampling_tech":sampling_tech,"result":result})

    print("")
    print("--------------------------------------")

# %%
test=df_preprocessed.sample(100).copy()

# %%
test_y = test.pop("success")
test_x = test

# %%
res = clf.predict(test_x)
res_probs = clf.predict_proba(test_x)[:, 1]
evaluate_model(test_y, res, res_probs)

# %%
df_sampled["ROS"][0].columns

# %%
len(df_sampled["ROS"][0])

# %%
X_train, X_test, y_train, y_test = train_test_split(df_sampled["ROS"][0], 
                                                    df_sampled["ROS"][1], 
                                                    test_size=0.2, 
                                                    random_state=47)

clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
y_probs = clf.predict_proba(X_test)[:, 1]
evaluate_model(y_test, y_pred, y_probs)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_sampled["RUS"][0].drop("previous_attempts",axis=1), 
                                                    df_sampled["RUS"][1], 
                                                    test_size=0.2, 
                                                    random_state=47)

clf = RandomForestClassifier()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
y_probs = clf.predict_proba(X_test)[:, 1]
evaluate_model(y_test, y_pred, y_probs)

# %%
from xgboost import XGBClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(df_sampled["ROS"][0].drop("previous_attempts",axis=1), 
                                                    df_sampled["ROS"][1], 
                                                    test_size=0.2, 
                                                    random_state=47)

clf = XGBClassifier()
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
y_probs = clf.predict_proba(X_test)[:, 1]
evaluate_model(y_test, y_pred, y_probs)

# %%
clf.feature_importances_

# %%
import matplotlib.pyplot as plt
importances = clf.feature_importances_
feature_names = [f"feature {i}" for i in range(df_sampled["ROS"][0].shape[1])]
std = np.std([tree.feature_importances_ for tree in clf.estimators_], axis=0)

forest_importances = pd.Series(importances, index=feature_names)

fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
df_sampled["ROS"][0].columns

# %%
len(df_sampled["ROS"][0].columns)

# %%
len(df_sampled["ROS"][0])

# %%
df_sampled["ROS"][0][df_sampled["ROS"][0].duplicated()]

# %%
from sklearn.inspection import permutation_importance

result = permutation_importance(
    clf, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)

forest_importances = pd.Series(result.importances_mean, index=feature_names)

# %%
fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=result.importances_std, ax=ax)
ax.set_title("Feature importances using permutation on full model")
ax.set_ylabel("Mean accuracy decrease")
fig.tight_layout()
plt.show()

# %%
df_sampled["ROS"][0].columns
